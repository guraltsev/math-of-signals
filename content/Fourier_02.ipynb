# %% [markdown]
# **TIP :** You can save your work offline to your computer (without risk of loss of data) by using `File->Download`. Later you can upload your creation back to the online environment using the "upload" button ![image.png](attachment:f7a1987b-cd16-466f-bb03-fc18851901bf.png) in the *file manager* sidebar:
#
# ![image.png](attachment:40c614cf-ca5b-42c0-acdf-3c3d29290525.png)
#
# **TIP :** If you mess up the notebook, you can start fresh by opening the link to this workspace in "incognito mode"

# %% [markdown]
# ## Environment
#
# This JupyterLite site already starts with `numpy`, `pandas`, `scipy`, `sympy`, `plotly`, `anywidget`, and `ipywidgets` available.
#
# Run the next cell to import the local helpers for this activity.

# %%
# Imports for this notebook
from gu_toolkit import *
from helpers.Fourier_02_helper import *

# %% [markdown]
# # Approximating a square wave using sine waves

# %% [markdown]
# We are looking at the (1-periodic) square wave. On $[-1/2, 1/2]$ it looks like this
#
# $$
# \mathrm{Sq}(x) = \begin{cases}-1 &\text{if } x<0 \\ 1 &\text{if } x>0 \end{cases}
# $$
#
# **Goal:** Find the numbers $a_n$ such that
# $$
# a_1 \sin(2π\, x)+a_2 \sin(2π\, 2x)+\ldots + a_N \sin(2π\, N x)
# $$
# is "close" to $\mathrm{Sq}(x)$.

# %% [markdown]
# ## The square wave
#
# Next we define and plot the square wave.
#
# Zoom out to see how it behaves over larger time intervals. Use the controls on the upper right to manipulate the graph.
#
# ![image.png](attachment:f31575c4-fa8a-4134-9226-f29d80e792e4.png)

# %%
@NamedFunction
def Sq(x):
    return sign(sin(2*pi*x))

# Display it on a figure.
fig_square = Figure(x_range=(-1 / 2, 1 / 2), y_range=(-2, 2))
fig_square.title = f"The square wave $\\mathrm{{Sq}}(x)$"
display(fig_square)

with fig_square:
    plot(x, Sq(x), id="Sq")
# Out:
# OneShotOutput()

# %% [markdown]
# ## Build a sine-sum model with adjustable parameters
#
# Now you will build a *model*:
# $$
# \sum_{n=1}^{N} a_n\,\sin(2\pi n x).
# $$
#
# with numbers $a_1,\dots,a_{N}$  *you control*.
#
# **Goal:** Use sliders to tune the numbers $a_1,a_2,\ldots$ so that your model matches the mystery function $\mathrm{Sq}(x)$.

# %% [markdown]
# ### Model and plot

# %% [markdown]
# **Question** How many modes are you going to use?
#
# The code below starts with $2$. You will probably need more. *First start with just two modes*
# ``` python
# # Model and plot
#
# ## Define the model
# model = a[1] * sin(2 * pi * 1 * x) + a[2] * sin(2 * pi * 2 * x)
# display(model)
#
# ## Create the Figure
# fig = Figure(x_range=(-1 / 2, 1 / 2), y_range=(-2.5, 2.5))
# fig.title = r"Fitting the model to $\mathrm{Sq}(x)$"
# display(fig)
#
# with fig:
#     plot(x, Sq(x), id="Sq(x)")
#     plot(x, model, id="model")
#
# ## Provide feeback on difference between Sq and model
# card = fig.add_info_component("info:Sq_minus_model_max_dist", MaxDistanceCard(x,Sq(x),model), hook_id="maxdist:Sq_minus_model")
# ```

# %% [markdown]
# **You do it:**
# - Use the suggested code below to plot the function $\mathrm{Sq}(x)$ and the model
# - Try to make the two curves overlap as closely as you can.

# %%
# Model and plot

## Define the model
model = a[1] * sin(2 * pi * 1 * x) + a[2] * sin(2 * pi * 2 * x)
display(model)

## Create the Figure 
fig = Figure(x_range=(-1 / 2, 1 / 2), y_range=(-2.5, 2.5))
fig.title = r"Fitting the model to $\mathrm{Sq}(x)$"
display(fig)

with fig:
    plot(x, Sq(x), id="Sq(x)")
    plot(x, model, id="model")

## Provide feeback on difference between Sq and model
card = fig.add_info_component("info:Sq_minus_model_max_dist", MaxDistanceCard(x,Sq(x),model), hook_id="maxdist:Sq_minus_model")
# Out:
# a_1*sin(2*pi*x) + a_2*sin(4*pi*x)
# OneShotOutput()

# %% [markdown]
# ## Question 1
#
# We are trying to get the largest distance between the function $\mathrm{Sq}(x)$ and the model to be smal. Can you make it smaller than $1$? Start by changing only $a_1$ and $a_2$.

# %% [markdown]
# ### Further investigation: plotting the partial sums and the difference

# %% [markdown]
# To understand this better, let us increase the numeber of parameters and define the *partial* sums:
# $$
# S_1(x)=a_1 \sin(2π\,x)
# $$
# $$
# S_2(x)=a_1 \sin(2π\,x)+ a_2 \sin(2π\,2x)
# $$
# $$
# S_3(x)=a_1 \sin(2π\,x)+ a_2 \sin(2π\,2x)+a_3 \sin(2π\,3x)
# $$
# and so on. To quickly generate multiple expressions and add them to the plot in Python we are going to use a loop:
# ```python
# Nmax = 8
# S = [0]
# for n in range(Nmax):
#     expr = S[-1] + a[n + 1] * sin(2 * pi * (n + 1) * x)
#     S.append(expr)
# for n in range(Nmax):
#     display(Latex(f"$S_{n + 1}(x)={latex(S[n + 1])}$"))
#     with fig:
#         plot(x, S[n + 1], id=f"S{n + 1}")
#
# # Update the model to be the sum with most components
# model=S[Nmax]
# with fig:
#     plot(x, model, id="model")
# ```
#
# **You do it:**
# - Create a new code cell using the toolbar and use the code above to define and plot the partial sums
# - Go back to the figure and see the new plots. You can turn each plot on and off by clicking on the *legend*.
# - Do not make `Nmax` too large. It is better not to exceed 12.
#
# *Note*: In python `range(n)` gives the integers from `0` to `n-1` (`n` is not included). That is why we use `n+1` in the expressions above

# %%
model
# Out:
# a_1*sin(2*pi*x) + a_2*sin(4*pi*x)

# %%
Nmax = 8
S = [0]
for n in range(Nmax):
    expr = S[-1] + a[n + 1] * sin(2 * pi * (n + 1) * x)
    S.append(expr)
for n in range(Nmax):
    display(Latex(f"$S_{n + 1}(x)={latex(S[n + 1])}$"))
    with fig:
        plot(x, a[n + 1] * sin(2 * pi * (n + 1) * x), id=f"A{n + 1}")
# Out:
# $S_1(x)=a_{1} \sin{\left(2 \pi x \right)}$
# $S_2(x)=a_{1} \sin{\left(2 \pi x \right)} + a_{2} \sin{\left(4 \pi x \right)}$
# $S_3(x)=a_{1} \sin{\left(2 \pi x \right)} + a_{2} \sin{\left(4 \pi x \right)} + a_{3} \sin{\left(6 \pi x \right)}$
# $S_4(x)=a_{1} \sin{\left(2 \pi x \right)} + a_{2} \sin{\left(4 \pi x \right)} + a_{3} \sin{\left(6 \pi x \right)} + a_{4} \sin{\left(8 \pi x \right)}$
# $S_5(x)=a_{1} \sin{\left(2 \pi x \right)} + a_{2} \sin{\left(4 \pi x \right)} + a_{3} \sin{\left(6 \pi x \right)} + a_{4} \sin{\left(8 \pi x \right)} + a_{5} \sin{\left(10 \pi x \right)}$
# $S_6(x)=a_{1} \sin{\left(2 \pi x \right)} + a_{2} \sin{\left(4 \pi x \right)} + a_{3} \sin{\left(6 \pi x \right)} + a_{4} \sin{\left(8 \pi x \right)} + a_{5} \sin{\left(10 \pi x \right)} + a_{6} \sin{\left(12 \pi x \right)}$
# ...

# %% [markdown]
# **Attention** To best fit the function $\mathrm{Sq}(x)$ you may need to allow $a_1,a_2, a_3$ to be larger than $1$. A reasonable limit is $2$.
#
# Adjust the limits for the parameters by clicking on them.
# ![image.png](attachment:52eedd11-50cf-4583-8d5a-641c9ff1523b.png)

# %% [markdown]
# ### The functions "look closer" but the maximum distance is still at least 1

# %% [markdown]
# Why does that happen? Try to plot the differences of $S_n(x)$ with $\mathrm{Sq}(x)$ using this loop:
# ```python
# for n in range(Nmax):
#     display(Latex(f"Plotting $\\mathrm{{Sq}}(x)-S_{n + 1}(x)$"))
#     with fig:
#         plot(x, Sq(x)-S[n + 1], id=f"Sq-S{n + 1}")
# ```
#
# **You do it:**
# - Create a code cell and run the code above
# - Try turning off all the plotted functions except *a few*. You want to make the differences **as close to 0 as possible** everywhere!

# %% [markdown]
# ## Question 2

# %% [markdown]
# In the experiment above, we saw that the functions $S_n$ "look like" they are closer to $\mathrm{Sq}(x)$ but still there are points (which are those "bad" points?) where they are far.
#
# Maybe measuring the "maximum distance" is not the right way to go.
#
# What if we measure the **average** distance? Add the `AvgDistanceCard` to the info output using this code
# ```python
# card2 = fig.add_info_component("info:Sq_minus_model_avg", AvgDistanceCard(x,Sq(x),S[Nmax]), hook_id="avgdist:Sq_minus_S_N")
#
# ```
#
# **You do it:**
# - Create a code cell and run the code above
# - How close can you get? Document your result with a screenshot. We will compare what we got when we next meet

# %%
card2 = fig.add_info_component("info:Sq_minus_model_avg", AvgDistanceCard(x,Sq(x),S[Nmax]), hook_id="avgdist:Sq_minus_S_N")

# %% [markdown]
# ## Question 3

# %% [markdown]
# Both visually and numerically. Do you think the even modes are helpful for approximating the square wave? Try to figure out why not.
#
# **You do it:**
# - Set all the parameters to $0$ and change only **one** of the **even** ones. What do you observe?
# - Set all the parameters to $0$ and change only **one** of the **odd** ones. What do you observe?

# %% [markdown]
# ### If even ones do not matter (advanced)...

# %% [markdown]
# If even ones do not matter, restart the notebook with ![image.png](attachment:2caaa9bc-0eee-4372-8750-24933bf72975.png). Then modify the loop to only add the odd terms. Do this by replacing the expressions in the loops to make them skip the even number. We use pythons division remainder operation: `n%d` gives the remainder of dividing `n` by `d` so `(n+1) % 2 != 0` is true only if `(n+1)` is odd.
#
# ------
#
# **1.**
# ``` python
#     expr = S[-1] + a[n + 1] * sin(2 * pi * (n + 1) * x)
# ```
# with
# ```
#     if (n+1) % 2 != 0:
#         expr = S[-1] + a[n + 1] * sin(2 * pi * (n + 1) * x)
#     else:
#         expr = S[-1] + 0 * sin(2 * pi * (n + 1) * x)
# ```
#
# ------
#
# **2.**
# ``` python
#     display(Latex(f"$S_{n + 1}(x)={latex(S[n + 1])}$"))
#     fig.plot(x, S[n + 1], id=f"S{n + 1}")
# ```
# with
# ```python
#     if (n+1) % 2 != 0:
#         display(Latex(f"$S_{n + 1}(x)={latex(S[n + 1])}$"))
#         fig.plot(x, S[n + 1], id=f"S{n + 1}")
# ```
#
# ------
#
# **3.**
# ``` python
#     display(Latex(f"Plotting $\\mathrm{{Sq}}(x)-S_{n + 1}(x)$"))
#     fig.plot(x, Sq(x)-S[n + 1], id=f"Sq-S{n + 1}")
# ```
# with
# ```python
#     if (n+1) % 2 != 0:
#         display(Latex(f"Plotting $\\mathrm{{Sq}}(x)-S_{n + 1}(x)$"))
#         fig.plot(x, Sq(x)-S[n + 1], id=f"Sq-S{n + 1}")
# ```
#
# You can then make `Nmax` much larger. Probably 20 will work without issue. Try it.
